# %% [markdown]
# # Short Introduction to JSON

# %%
#https://www.w3schools.com/python/python_json.asp
import json
import pandas as pd

# %% [markdown]
# (Note: API return is usually in JSON format. pandas here is to help wrangle json data.)

# %%
'''
Using pd.read_json
https://pandas.pydata.org/docs/reference/api/pandas.read_json.html

Structure of iris.json 
- top-level structure array ([]) 
- each object is a single record with key value pairs in ({})
'''

# Pandas read_json function
pd.read_json('iris.json').head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
type(pd.read_json('iris.json'))
# Out:
# pandas.core.frame.DataFrame

# %%
# Pandas read_json function
# Using this for food.json file will lead to error
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering (### > json data is semi-structured)

pd.read_json('food.json').head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 5
#       1 # Pandas read_json function
#       2 # Using this for food.json file will lead to error
#       3 # ValueError: Mixing dicts with non-Series may lead to ambiguous ordering
# ----> 5 pd.read_json('food.json').head()
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:757, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     754     return json_reader
#     756 with json_reader:
# --> 757     return json_reader.read()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:915, in JsonReader.read(self)
#     913         obj = self._get_object_parser(self._combine_lines(data_lines))
#     914 else:
# --> 915     obj = self._get_object_parser(self.data)
#     916 self.close()
#     917 return obj
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:937, in JsonReader._get_object_parser(self, json)
#     935 obj = None
#     936 if typ == "frame":
# --> 937     obj = FrameParser(json, **kwargs).parse()
#     939 if typ == "series" or obj is None:
#     940     if not isinstance(dtype, bool):
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:1064, in Parser.parse(self)
#    1062     self._parse_numpy()
#    1063 else:
# -> 1064     self._parse_no_numpy()
#    1066 if self.obj is None:
#    1067     return None
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:1320, in FrameParser._parse_no_numpy(self)
#    1317 orient = self.orient
#    1319 if orient == "columns":
# -> 1320     self.obj = DataFrame(
#    1321         loads(json, precise_float=self.precise_float), dtype=None
#    1322     )
#    1323 elif orient == "split":
#    1324     decoded = {
#    1325         str(k): v
#    1326         for k, v in loads(json, precise_float=self.precise_float).items()
#    1327     }
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:669, in _extract_index(data)
#     666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
# --> 669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#     673 if have_series:
#     674     assert index is not None  # for mypy
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
'''
Using
Python json.load first and then pd.DataFrame or pd.json_normalize

Structure of food.json
- dictionary with nested dictionaries and lists
'''
with open('food.json') as data:    
    data = json.load(data) # Decode JSON object to Python dict

# %%
type(data)

# %%
#one may want to view the JSON data to review where is the data of interest.
data

# %%
### > "results" is the key, and the things we are interested are the values in it
data['results']
# Out:
# [{'status': 'Ongoing',
#   'city': 'Seattle',
#   'state': 'WA',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92830',
#   'recalling_firm': 'David Oppenheimer & Company I LLC',
#   'address_1': '180 Nickerson St Ste 211',
#   'address_2': '',
#   'postal_code': '98109-1631',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'Distributed in FL, GA, IL, IN, KY, MI, NC, NY, OH, PA, TN, TX, VA, and WI.',
#   'recall_number': 'F-1495-2023',
#   'product_description': 'Zespri Organic Green Kiwi, product of New Zealand, one pallet of bulk loose organic green kiwifruit was shipped to one consignee in Chicago, IL. The master carton has the barcode 067834 and the kiwi PLU label has the code GTIN 9400 9552.',
#   'product_quantity': '1 pallet',
#   'reason_for_recall': 'Listeria monocytogenes',
#   'recall_initiation_date': '20230808',
#   'center_classification_date': '20230908',
#   'report_date': '20230920',
#   'code_info': 'none',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Dayton',
#   'state': 'OH',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92888',
#   'recalling_firm': 'Cassanos Inc',
#   'address_1': '1700 E Stroop Rd',
#   'address_2': '',
#   'postal_code': '45429-5040',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Letter',
#   'distribution_pattern': 'OH',
#   'recall_number': 'F-1510-2023',
#   'product_description': "Cassano's The Pizza King Premium Pizza Dough on Parchment: packaged as  16in (regular)",
#   'product_quantity': '180',
#   'reason_for_recall': 'Undeclared Allergen - Soy Flour',
#   'recall_initiation_date': '20230821',
#   'center_classification_date': '20230913',
#   'termination_date': '20230915',
#   'report_date': '20230920',
#   'code_info': 'Lot: 193, 194 Expiration: 01/10/24, 01/11/24 Item No. 1002',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Englewood Cliffs',
#   'state': 'NJ',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92853',
#   'recalling_firm': 'Conopco DBA Unilever',
#   'address_1': '700 Sylvan Ave',
#   'address_2': '',
#   'postal_code': '07632-3113',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'Distributed nationwide.',
#   'recall_number': 'F-1516-2023',
#   'product_description': 'Knorr Letras con Tomate Tomato Based Alphabet Pasta Soup Mix 3.5 oz UPC: 048001716186',
#   'product_quantity': '230,000 cases',
#   'reason_for_recall': 'Undeclared egg',
#   'recall_initiation_date': '20230810',
#   'center_classification_date': '20230913',
#   'report_date': '20230920',
#   'code_info': 'Best buy dates prior to and including July 6, 2024',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Stanwood',
#   'state': 'WA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92907',
#   'recalling_firm': 'Twin City Foods, Inc.',
#   'address_1': '10120 269th Pl Nw Ste A',
#   'address_2': '',
#   'postal_code': '98292-4736',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'E-Mail',
#   'distribution_pattern': 'distributed nationwide in the US and in Costa Rica, China, and Japan.',
#   'recall_number': 'F-1504-2023',
#   'product_description': 'Individually Quick Frozen (IQF) Corn, distributed in bulk cases (1kg, 10kg, 12kg, 15kg, 25kg) to consignees for further processing.  Cases are read in parts: Product of U.S.A. Packed By Twin City Foods, Inc. Stanwood, Washington.  Super Sweet Grade A Cut Corn Blanched Vegetables, net wt. 12kg (12/1kg bags per case). Super Sweet Grade A Cut Corn Blanched Vegetable, net wt. 10kg Super Sweet Cut Corn Blanched Vegetables, net wt. 12kg Super Sweet Cut Corn Blanched Vegetables, LARGE, net wt. 12kg Super Sweet Grade A Cut Corn Blanched Vegetables, net wt. 15kg Super Sweet Grade A Triple Clean Cut Corn Blanched Vegetables, net wt. 15kg Super Sweet Grade A Cut Corn Blanched Vegetables, net wt. 25kg Super Sweet Grade A Triple Clean Cut Corn, net wt. 25kg',
#   'product_quantity': 'Bulk Cases Total 69,134 cs (Corn 12/1kg bags = 8,792 cs; Corn 10kg = 2,389 cs; Corn 12kg = 38,127kg; Corn 15kg = 4,729 cs; Corn 25kg = 15,097 cs)',
#   'reason_for_recall': 'Listeria monocytogenes',
#   'recall_initiation_date': '20230818',
#   'center_classification_date': '20230912',
#   'report_date': '20230920',
#   'code_info': 'BULK CASES have the following codes and USE BY DATES:  Super Sweet Grade A Cut Corn Blanched Vegetables, net wt. 12kg (12/1kg bags per case) has the USE BY dates: 2024.12.21 81723  2024.12.23 81743  2025.01.03 81843  Super Sweet Corn, net wt. 10kg, has the USE BY dates:  2025.06.22 31733 553293 330695  2025.06.23 31743 553293 330697   Super Sweet Cut Corn Blanched Vegetables, net wt. 12kg, has the USE BY dates:  2024.12.28 33622 553062 330246 2025.05.26 31463 553062 330621 2025.05.31 31513 553062 330633  Super Sweet Cut Corn Blanched Vegetables, LARGE, net wt. 12kg, has the USE BY dates:  2024.12.06 33402 553172 330193  2024.12.07 33412 553172 330197  2024.12.15 33492 553172 330227 2025.01.06 30063 553172 330266  2025.01.10 30103 553172 330275  2025.01.09 30093 553172 330270  2025.01.11 30113 553172 330279  2025.01.19 30193 553172 330311  2025.01.20 30203 553172 330313  2025.01.24 30243 553172 330329  2025.01.27 30273 553172 330342  2025.01.30 30303 553172 330347  2025.02.01 30323 553172 330355  2025.06.27 31783 553173 330703   Super Sweet Corn, net wt. 15kg, has the USE BY dates:  2025.05.15 31353 553032 330599   Super Sweet Corn Triple Clean, net wt. 15kg, has the USE BY dates:  USE BY 2025.03.01 30603 555472 330407 USE BY 2025.06.19 31703 555473 330681  Super Sweet Cut Corn, net wt. 25kg, has the USE BY dates:  USE BY 2025.05.10 31303 551932 330588 USE BY 2025.05.12 31323 551932 330595  Super Sweet Grade A Triple Clean Cut Corn, net wt. 25kg, has the USE BY dates:  2025.02.09 30403 553012 330377  2025.03.01 30603 553012 330409  2025.03.03 30623 553012 330415  2025.04.19 31093 553012 330534  2025.05.11 31313 553012 330592  2025.05.12 31323 553012 330596  2025.05.17 31373 553012 330605  2025.05.30 31503 553012 330630',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Stanwood',
#   'state': 'WA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92907',
#   'recalling_firm': 'Twin City Foods, Inc.',
#   'address_1': '10120 269th Pl Nw Ste A',
#   'address_2': '',
#   'postal_code': '98292-4736',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'E-Mail',
#   'distribution_pattern': 'distributed nationwide in the US and in Costa Rica, China, and Japan.',
#   'recall_number': 'F-1505-2023',
#   'product_description': 'Kernel Corn, BEST PRICE TOPVALU, net wt. per bag 300g. Label is in foreign language. UPC 4549414086232  Signature Select Golden Corn Super Sweet, Product of USA, net wt. per bag 12oz, 12 bags per case. UPC 21130090655  Food Lion Super Sweet Cut Yellow Corn, Product of USA, net wt. per bag 16oz, 12 bags per case. Distributed by Food Lion, LLC Salisbury, NC. UPC 35826079855  Kroger Super Sweet Corn, Product of USA, net wt. per bag 12oz, 14 bags per case. Distributed by The Kroger C. Cincinnati, OH. UPC 11110849618  Kroger Super Sweet Corn, Product of USA, net wt. per bag 32oz, 6 bags per case. Distributed by The Kroger C. Cincinnati, OH. UPC 11110865786',
#   'product_quantity': 'TopValu 300g = 1,108 cs; Signature Select = 1,979 cs; Food Lion = 6,727 cs; Kroger 12oz = 64,668 cs; Kroger 32oz = 14,786 cs.',
#   'reason_for_recall': 'Listeria monocytogenes',
#   'recall_initiation_date': '20230818',
#   'center_classification_date': '20230912',
#   'report_date': '20230920',
#   'code_info': 'BEST PRICE TOPVALU: 2024.02.23  Signature Select: BEST IF USED BY FEB.22.24 S5716  Food Lion: 53072 BEST BY 03 NOV 2024  Food Lion: 53622 BEST BY 28 DEC 2024  Kroger 12oz: 52842 BEST IF USED BY APR 2024  53042 BEST IF USED BY APR 2024  53272 BEST IF USED BY MAY 2024  53542 BEST IF USED BY JUN 2024  50043 BEST IF USED BY JUL 2024  50033 BEST IF USED BY JUL 2024  BEST IF USED BY APR.2024 82842 BEST IF USED BY FEB.2024 82352  Kroger 32oz.  53052 BEST IF USED BY MAY 2024  53112 BEST BY MAY 2024 BEST IF USED BY APR.2024 82932 BEST IF USED BY APR.2024 83012',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Saint Paul',
#   'state': 'MN',
#   'country': 'United States',
#   'classification': 'Class III',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92870',
#   'recalling_firm': 'Twin Cities Co-Op Partners Inc.',
#   'address_1': '744 Vandalia St',
#   'address_2': '',
#   'postal_code': '55114-1303',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'IA, MI, MN, WI',
#   'recall_number': 'F-1498-2023',
#   'product_description': 'La Reyna Guacamole, Gluten Free.  Product Code 1780.  Net Wt 16 oz.  UPC 7 52830-92610 3.  Ingredients:  Avocado, Tomato, Cilantro, Salt, Onions.  Keep Refrigerated.  La Reyna, 202 4th, Vinton IA  42349',
#   'product_quantity': '720 containers total',
#   'reason_for_recall': 'Dips and sauces received out of temperature specifications. Product was not quarantined; product was shipped to customers.',
#   'recall_initiation_date': '20230811',
#   'center_classification_date': '20230908',
#   'termination_date': '20230913',
#   'report_date': '20230920',
#   'code_info': 'Lot codes to be updated - includes dips and sauces shipped from warehouse since Friday, August 5, 2023.',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Saint Paul',
#   'state': 'MN',
#   'country': 'United States',
#   'classification': 'Class III',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92870',
#   'recalling_firm': 'Twin Cities Co-Op Partners Inc.',
#   'address_1': '744 Vandalia St',
#   'address_2': '',
#   'postal_code': '55114-1303',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'IA, MI, MN, WI',
#   'recall_number': 'F-1500-2023',
#   'product_description': 'La Reyna Queso Dip.  Product Code 1781.  Net Wt 16 oz.  UPC 7 52830-92650 9.  Keep Refrigerated.  Ingredients:   American White Cheese, 2% Milk, White Vinegar, Onion, Salt, Jalapeno Peppers.  La Reyna, 202 4th, Vinton IA  42349',
#   'product_quantity': '720 containers total',
#   'reason_for_recall': 'Dips and sauces received out of temperature specifications. Product was not quarantined; product was shipped to customers.',
#   'recall_initiation_date': '20230811',
#   'center_classification_date': '20230908',
#   'termination_date': '20230913',
#   'report_date': '20230920',
#   'code_info': 'Lot codes to be updated - includes dips and sauces shipped from warehouse since Friday, August 5, 2023.',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Jacksonville',
#   'state': 'FL',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92890',
#   'recalling_firm': "Shaw's Southern Belle Frozen Foods, Inc.",
#   'address_1': '821 Virginia St',
#   'address_2': '',
#   'postal_code': '32208-4950',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'Domestic distribution only.',
#   'recall_number': 'F-1507-2023',
#   'product_description': 'Southern Belle Seafood Crabmeat Stuffing, Packed: 2/25 lb. Bag, Net Weight: 50 lb. (22.68 kg), Use By: 08/23/2023',
#   'product_quantity': '600 lbs',
#   'reason_for_recall': 'A piece of brittle plastic was found in seafood crabmeat stuffing mix.',
#   'recall_initiation_date': '20230814',
#   'center_classification_date': '20230912',
#   'report_date': '20230920',
#   'code_info': 'Use By: 08/23/2023 Lot # 042504',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Saint Paul',
#   'state': 'MN',
#   'country': 'United States',
#   'classification': 'Class III',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92870',
#   'recalling_firm': 'Twin Cities Co-Op Partners Inc.',
#   'address_1': '744 Vandalia St',
#   'address_2': '',
#   'postal_code': '55114-1303',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'IA, MI, MN, WI',
#   'recall_number': 'F-1499-2023',
#   'product_description': 'La Reyna Salsa Roja, Gluten Free / Medium.  Product Code 1783.  Net Wt 16 oz.  UPC 7 52830-92630 1.  Keep Refrigerated.  La Reyna, 202 4th, Vinton IA  42349',
#   'product_quantity': '720 Containers total',
#   'reason_for_recall': 'Dips and sauces received out of temperature specifications. Product was not quarantined; product was shipped to customers.',
#   'recall_initiation_date': '20230811',
#   'center_classification_date': '20230908',
#   'termination_date': '20230913',
#   'report_date': '20230920',
#   'code_info': 'Lot codes to be updated - includes dips and sauces shipped from warehouse since Friday, August 5, 2023.',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Middleburg',
#   'state': 'FL',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92934',
#   'recalling_firm': 'Todorganic Inc.',
#   'address_1': '4071 White Bark Plantation Dr',
#   'address_2': '',
#   'postal_code': '32068-3438',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'Domestic distribution only.',
#   'recall_number': 'F-1513-2023',
#   'product_description': 'TODRGANIC Natural Products, NUEZ DE LA INDIA, Natural Products, 12 Seeds 12 Semillas',
#   'product_quantity': 'Unknown',
#   'reason_for_recall': 'Product appears to be Yellow Oleander instead of Nuez de la India as labeled.',
#   'recall_initiation_date': '20230825',
#   'center_classification_date': '20230913',
#   'report_date': '20230920',
#   'code_info': 'Lot 168, EXP 10/24',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Englewood Cliffs',
#   'state': 'NJ',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92853',
#   'recalling_firm': 'Conopco DBA Unilever',
#   'address_1': '700 Sylvan Ave',
#   'address_2': '',
#   'postal_code': '07632-3113',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'Distributed nationwide.',
#   'recall_number': 'F-1515-2023',
#   'product_description': 'Knorr Fideos con Tomate Tomato Based Pasta Soup Mix 3.5 oz UPC: 048001716162',
#   'product_quantity': '530,000 cases',
#   'reason_for_recall': 'Undeclared egg',
#   'recall_initiation_date': '20230810',
#   'center_classification_date': '20230913',
#   'report_date': '20230920',
#   'code_info': 'Best buy dates prior to and including July 6, 2024',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Arlington',
#   'state': 'VA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92869',
#   'recalling_firm': 'Nestle-USA, Inc. (Corporate Office)',
#   'address_1': '1812 N Moore St',
#   'address_2': '',
#   'postal_code': '22209-1804',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'The recalled product was distributed to the following states: AZ,LA,NH,MN.KS,NE,MO,FL,CA,TX,VA,PA,ME,NC,NY,TX,KY,TN,IN,MI,UT,WI,OH,MN,CO,MI,IL,IA,KY,MS,AL,OK',
#   'recall_number': 'F-1491-2023',
#   'product_description': 'Nestle Toll House, Chocolate Chip Cookie Dough, 16.5 oz. Cookie dough in bar form packaged in paperboard tray with plastic overwrap, 12 packages per case, Keep Refrigerated',
#   'product_quantity': '12,318 total cases (147,816 total packages) (12 cases destroyed due to warehouse damage at Nestle USA controlled DC)',
#   'reason_for_recall': 'Potential presence of wood fragments.',
#   'recall_initiation_date': '20230810',
#   'center_classification_date': '20230901',
#   'report_date': '20230913',
#   'code_info': 'Batch Numbers:  311457531K and 311557534K  Best By Dates:  8/22/23 and 10/23/23'},
#  {'status': 'Completed',
#   'city': 'Georgia',
#   'state': 'VT',
#   'country': 'United States',
#   'classification': 'Class III',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92569',
#   'recalling_firm': 'PBM Nutritionals, LLC',
#   'address_1': '147 Industrial Park Rd',
#   'address_2': '',
#   'postal_code': '05468-2109',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Telephone',
#   'distribution_pattern': 'IL, AL, IA, GA, MS, IN, AR, CO, FL, VA, OH, WI, PA, NH, AZ, KS, TX, TN, NC, LA, MO, KY, DE, WI',
#   'recall_number': 'F-1493-2023',
#   'product_description': "Parent's Choice brand Sensitivity Premium Infant Formula, 638g, packaged in plastic tubs; and Tippy Toes brand Sensitivity Premium Infant Formula, 942g, packaged in composite cans",
#   'product_quantity': '',
#   'reason_for_recall': 'Inadvertent release of rejected product to market',
#   'recall_initiation_date': '20230616',
#   'center_classification_date': '20230906',
#   'report_date': '20230913',
#   'code_info': 'D05LVJV USE BY 05MAR2025 D06LT7VA USE BY 06MAR2025  UPC Codes: 36800496644 and 681131045513'},
#  {'status': 'Ongoing',
#   'city': 'Houston',
#   'state': 'TX',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92924',
#   'recalling_firm': 'TEXAS TAMALE COMPANY',
#   'address_1': '14453 Hillcroft St Ste 200',
#   'address_2': '',
#   'postal_code': '77085-1536',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'Texas',
#   'recall_number': 'F-1522-2023',
#   'product_description': 'Texas Tamale Black Bean Tamales  18 oz, (1 lb. 2 oz), 510 g',
#   'product_quantity': '204 cases/1632 units',
#   'reason_for_recall': 'Contains undeclared milk.',
#   'recall_initiation_date': '20230821',
#   'center_classification_date': '20230918',
#   'report_date': '20230920',
#   'code_info': 'Batch Number: 06192025 Lot Number: 17023',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Bellingham',
#   'state': 'WA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92658',
#   'recalling_firm': 'Bellingham Pasta Co',
#   'address_1': '3125 Mercer Ave Ste 101',
#   'address_2': '',
#   'postal_code': '98225-8435',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'Distributed in WA.',
#   'recall_number': 'F-1372-2023',
#   'product_description': 'Pasta - Mixed Flavors case.  Firm did not provide label.',
#   'product_quantity': '168 packages',
#   'reason_for_recall': 'Pasta label declares semolina flour but does not declare wheat.',
#   'recall_initiation_date': '20230703',
#   'center_classification_date': '20230804',
#   'termination_date': '20230913',
#   'report_date': '20230816',
#   'code_info': 'Best By Dates 7/12, 7/15, and 7/19.'},
#  {'status': 'Completed',
#   'city': 'Keene',
#   'state': 'NH',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92757',
#   'recalling_firm': 'C & S Wholesale Grocers Inc.',
#   'address_1': '7 Corporate Dr',
#   'address_2': '',
#   'postal_code': '03431-5042',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'NY, NJ, CT',
#   'recall_number': 'F-1462-2023',
#   'product_description': "The following items sold at Stop & Shop stores located in the New York Metro Region:  Bolthouse Avocado Goddess Dressing Bolthouse Blue Cheese Dressing Bolthouse Caesar Dressing Bolthouse Cucumber Ranch Dressing Marzetti Light Ranch Veg Dip Marzetti French Onion Veg Dip Marzetti Spinach Veg Dip Marzetti Simply Dressed Lemon Vinagrete Marzetti Simply Dressed Ranch Dressing Marzetti Simply Dressed Caesar Makoto Ginger Dressing Bolthouse Chunky Blue Cheese Dressing Maries Chunky Blue Cheese Dressing Maries Creamy Ranch Dressing Maries White Balsamic Vinagret Maries Garlic Parm Italian Vinagret Maries Coleslaw Dressing Maries Super Blue Cheese Dressing Maries Chunky Blue Cheese Dressing Panera Caesar Dressing Bolthouse Ranch Dressing Marzetti Supreme Caesar Dressing Marzett 100 cal fruit dip Wholly Guacamole Chunky Wholly Gucamole Classic Wholly Guacamole Organic Minis Wholly Guacamole Salsa Verde  Mitchell's Chipotle Salsa Mitchell's Medium Salsa Mitchell's Mild Salsa Calavo Authentic Gucamole La Mexicana Medium Salsa La Mexicana Mild Salsa Panera Poppyseed Dressing Panera Balsamic Dressing Bolthouse Cilantro Avocado Dressing Bolthouse Ranch Dressing La Mexicana Hot Salsa Italian Rose Bruschetta Light Dill Vegetable Dip Ranch Vegetable Dip Simply Avocado Dressing Wholly Guacamole Chunky Maries Balsamic Vinaigrette Dressing Maries Caesar Dressing  Maries Blue Cheese Dressing  Maries Italian Vinaigrette Dressing Chunky Blue Cheese Dressing Classic Ranch Dressing Pom Wonderful Blueberry Juice Calavo Fresh Pico Guacamole Garden Fresh Jack's Special Medium Salsa",
#   'product_quantity': '29,469 cases of various products, styles of pack, case sizes and counts',
#   'reason_for_recall': 'Perishable products were not held at an appropriate temperature.',
#   'recall_initiation_date': '20230719',
#   'center_classification_date': '20230825',
#   'report_date': '20230906',
#   'code_info': 'Unit UPCs: *0714640227 *0714640228 *0714640227 *0714640228 7020052208 7020052203 7020052205 *0702005342 *0702005342 7020055457 5576300025 714640218 7184005080 7184004281 7184020212 7184020217 7184004330 7184009012 7184009203 *0189591400 *0714640218 7020050439 *0702005406 1611286876 1611286875 1611269823 1611280257 5672400504 9450400504 8907607250 7074061610 *0201130015 *0201130015 *0189591400 *0189591400 0714640227 0714640228 0201130014 0777189980 7020052206 7020052200 0702005342 1611202855 7184009112 7184004934 7184005081 7184004253 7020050421 7020050425 2415040448 7074061612 4767100014'},
#  {'status': 'Ongoing',
#   'city': 'Miamisburg',
#   'state': 'OH',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92998',
#   'recalling_firm': 'Killer Brownie Ltd',
#   'address_1': '650 Precision Ct',
#   'address_2': '',
#   'postal_code': '45342-6138',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'E-Mail',
#   'distribution_pattern': 'Distributed to IL',
#   'recall_number': 'F-1512-2023',
#   'product_description': 'US Foods: Peanut Butter Toffee Bar, 3.4oz unit size, packaged in flow wrap, 24 packages per case',
#   'product_quantity': '82,080 units',
#   'reason_for_recall': 'Foreign Material - Plastic',
#   'recall_initiation_date': '20230831',
#   'center_classification_date': '20230913',
#   'report_date': '20230920',
#   'code_info': 'Lot No. 203KB650PR3, 203KB650MX3 Product No. 1020435',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Dayton',
#   'state': 'OH',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92888',
#   'recalling_firm': 'Cassanos Inc',
#   'address_1': '1700 E Stroop Rd',
#   'address_2': '',
#   'postal_code': '45429-5040',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Letter',
#   'distribution_pattern': 'OH',
#   'recall_number': 'F-1511-2023',
#   'product_description': "Ritchie's Distribution Pizza Dough on Parchment: packaged as 16in (regular)",
#   'product_quantity': '195',
#   'reason_for_recall': 'Undeclared Allergen - Soy Flour',
#   'recall_initiation_date': '20230821',
#   'center_classification_date': '20230913',
#   'termination_date': '20230915',
#   'report_date': '20230920',
#   'code_info': 'Lot: 193, 194 Expiration: 01/10/24, 01/11/24 Item No. 4118, 4119',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Seattle',
#   'state': 'WA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92649',
#   'recalling_firm': 'Sweet Alchemy Ice Creamery, Inc',
#   'address_1': '4301 University Way Ne',
#   'address_2': '',
#   'postal_code': '98105-5808',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'E-Mail',
#   'distribution_pattern': 'Distributed in WA only.',
#   'recall_number': 'F-1392-2023',
#   'product_description': 'Sweet Alchemy UW Honey ice cream, distributed in pints. Label declares company name, flavor name, but does not declare ingredients and allergens.',
#   'product_quantity': '12 pints',
#   'reason_for_recall': "Ice cream grab n go Pint containers' labels do not declare any ingredients including allergens Egg and Milk.",
#   'recall_initiation_date': '20230630',
#   'center_classification_date': '20230808',
#   'termination_date': '20230911',
#   'report_date': '20230816',
#   'code_info': 'No manufacturing code & expiration dates range from 7/30/2023 to 8/21/2023.'},
#  {'status': 'Terminated',
#   'city': 'Saint Paul',
#   'state': 'MN',
#   'country': 'United States',
#   'classification': 'Class III',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92870',
#   'recalling_firm': 'Twin Cities Co-Op Partners Inc.',
#   'address_1': '744 Vandalia St',
#   'address_2': '',
#   'postal_code': '55114-1303',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'IA, MI, MN, WI',
#   'recall_number': 'F-1497-2023',
#   'product_description': 'La Reyna Salsa Verde, Gluten Free / Medium.  Product Code 1784.  Net Wt 16 oz.  UPC 7 52830-92640 0.  Ingredients:  Tomatillo, Jalapenos, Onions, Garlic, Salt.  Keep Refrigerated.  La Reyna, 202 4th, Vinton IA  42349',
#   'product_quantity': '720 containers total',
#   'reason_for_recall': 'Dips and sauces received out of temperature specifications. Product was not quarantined; product was shipped to customers.',
#   'recall_initiation_date': '20230811',
#   'center_classification_date': '20230908',
#   'termination_date': '20230913',
#   'report_date': '20230920',
#   'code_info': 'Best By:  8/18/2023',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Stanwood',
#   'state': 'WA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92907',
#   'recalling_firm': 'Twin City Foods, Inc.',
#   'address_1': '10120 269th Pl Nw Ste A',
#   'address_2': '',
#   'postal_code': '98292-4736',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'E-Mail',
#   'distribution_pattern': 'distributed nationwide in the US and in Costa Rica, China, and Japan.',
#   'recall_number': 'F-1506-2023',
#   'product_description': 'Mixed Vegetables BEST PRICE TOPVALU, net per bag 500g. Label is in foreign language. 4549414484120  Food Lion Mixed Vegetables Carrots, Corn, Green Beans & Peas. Product of USA, net wt. per bag 16oz, 12 bags per case. Distributed by Food Lion, LLC Salisbury, NC. UPC 35826005090  Kroger Mixed Vegetables Carrots, Super Sweet Corn, Green Beans & Green Peas. Product of USA, net wt. per bag 12oz, 14 bags per case. Distributed by The Kroger C. Cincinnati, OH. UPC 11110849625  Kroger Mixed Vegetables Carrots, Super Sweet Corn, Green Beans & Green Peas. Product of USA, net wt. per bag 32oz, 6 bags per case. Distributed by The Kroger C. Cincinnati, OH. UPC 11110865854',
#   'product_quantity': 'TopValu = 163 cs; Food Lion = 2,728 cs; Kroger 12oz = 36,370 cs; Kroger 32oz = 3,084 cs.',
#   'reason_for_recall': 'Listeria monocytogenes',
#   'recall_initiation_date': '20230818',
#   'center_classification_date': '20230912',
#   'report_date': '20230920',
#   'code_info': 'BEST PRICE TOPVALU: 2025.01.06  Food Lion: 50183 BEST BY 18 JAN 2025   Kroger 12oz: 53122 BEST IF USED BY MAY 2024  53412 BEST IF USED BY JUN 2024 BEST IF USED BY APR.2024 82942 BEST IF USED BY APR.2024 83012 BEST IF USED BY AUG.2024 80463  Kroger 32oz.  BEST IF USED BY FEB.2024 82352',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Oak Brook',
#   'state': 'IL',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92905',
#   'recalling_firm': 'Treehouse Foods',
#   'address_1': '2021 Spring Rd Ste 600',
#   'address_2': '',
#   'postal_code': '60523-1860',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Other',
#   'distribution_pattern': 'CA CT FL IL PA TX WA',
#   'recall_number': 'F-1483-2023',
#   'product_description': "Trader Joe's Multigrain Crackers with Sunflower and Flax Seeds, 10oz (283g) box, UPC 000000761567, 24 retail boxes per wholesale case",
#   'product_quantity': '13,132 cases',
#   'reason_for_recall': 'pieces of metal found in the product',
#   'recall_initiation_date': '20230815',
#   'center_classification_date': '20230830',
#   'report_date': '20230906',
#   'code_info': 'Lot Code - 1GF06053  BEST IF Used By Date - 03 01 24 Lot Code - 1GF06063  BEST IF Used By Date - 03 02 24 Lot Code - 1GF06073  BEST IF Used By Date - 03 03 24 Lot Code - 1GF06083  BEST IF Used By Date - 03 04 24 Lot Code - 1GF06093  BEST IF Used By Date - 03 05 24'},
#  {'status': 'Completed',
#   'city': 'York',
#   'state': 'ME',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92876',
#   'recalling_firm': 'Stonewall Kitchen, LLC',
#   'address_1': '2 Stonewall Ln',
#   'address_2': '',
#   'postal_code': '03909-1662',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'ME, NH, MA, CT',
#   'recall_number': 'F-1476-2023',
#   'product_description': 'Stonewall Kitchen brand Peanut Butter Maltballs packaged in 6oz clear plastic packaging',
#   'product_quantity': '635 units',
#   'reason_for_recall': 'Product may contain undeclared peanut, soy, and wheat.',
#   'recall_initiation_date': '20230814',
#   'center_classification_date': '20230828',
#   'report_date': '20230906',
#   'code_info': 'DEC31 2024'},
#  {'status': 'Terminated',
#   'city': 'Sylmar',
#   'state': 'CA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92762',
#   'recalling_firm': 'Fantasy Cookie Corporation',
#   'address_1': '12800 Arroyo St',
#   'address_2': '',
#   'postal_code': '91342-5301',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'U.S. distribution to the following: PA, FL, CA, TX, IL, WA, CA, AZ, CT  No foreign distribution.',
#   'recall_number': 'F-1508-2023',
#   'product_description': "Trader Joe's Almond Windmill Cookies Buttery, tender cookies topped with crunchy almonds. Net Wt. 15 oz.",
#   'product_quantity': '76,560 units',
#   'reason_for_recall': 'Foreign object; rocks.',
#   'recall_initiation_date': '20230724',
#   'center_classification_date': '20230912',
#   'termination_date': '20230919',
#   'report_date': '20230920',
#   'code_info': '10/02/2023 A6, 10/02/2023 B6, 10/19/2023 A6, 10/19/2023 B6. 10/20/2023 A6, 10/20/2023 B6, 10/21/2023 A6, and 10/21/2023 B6.',
#   'more_code_info': ''},
#  {'status': 'Completed',
#   'city': 'Keene',
#   'state': 'NH',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92757',
#   'recalling_firm': 'C & S Wholesale Grocers Inc.',
#   'address_1': '7 Corporate Dr',
#   'address_2': '',
#   'postal_code': '03431-5042',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'NY, NJ, CT',
#   'recall_number': 'F-1465-2023',
#   'product_description': 'The following items sold at Stop & Shop stores located in the New York Metro Region:  JSL Fortune Yakisoba JSL Dragon Wonton Wrap Nasoya Shiratake Fettucine JSL Original Stirfry Noodle Nasoya Large Tofu Vegetable Dumpling Twin Dragon Egg Roll Wrapper JSL Stir Fry Noodles',
#   'product_quantity': '29,469 cases of various products, styles of pack, case sizes and counts',
#   'reason_for_recall': 'Perishable products were not held at an appropriate temperature.',
#   'recall_initiation_date': '20230719',
#   'center_classification_date': '20230825',
#   'report_date': '20230906',
#   'code_info': 'Unit UPCs: 7049203883 7469901023 2548400000 7049203860 2548400815 7469901025 7049200000'},
#  {'status': 'Ongoing',
#   'city': 'Rockwall',
#   'state': 'TX',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92665',
#   'recalling_firm': 'Pegasus Foods, Inc.',
#   'address_1': '1635 Innovation Dr',
#   'address_2': '',
#   'postal_code': '75032-6218',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'CA',
#   'recall_number': 'F-1501-2023',
#   'product_description': 'Cream Cheese Rangoon NET WT: 5.00 LB. (2.26 KG) CT/CS: 100 PS (5 TRAYS X 20 PCS UPC: (01)10664383187016(15)112823(10)0601233A1W package in corrugated cardboard case.',
#   'product_quantity': '38,887 cs. / 193,435 lbs.',
#   'reason_for_recall': 'Plastic foreign object found in product.',
#   'recall_initiation_date': '20230626',
#   'center_classification_date': '20230909',
#   'report_date': '20230920',
#   'code_info': 'Product Code: 18701  Lot Codes: 05-30-23-3A1W 06-01-23-3B1W 06-06-23-3A1W 06-08-23-4A1W 05-30-23-3B1W 06-01-23-4A1W 06-06-23-3B1W 06-09-23-3B1W 05-30-23-4A1W 06-02-23-3A1W 06-06-23-4A1W 06-23-23-3A1W 05-31-23-3A1W 06-02-23-3B1W 06-07-23-3A1W 06-23-23-3B1W 05-31-23-3B1W 06-05-23-3A1W 06-07-23-3B1W 06-26-23-3A1W 05-31-23-4A1W 06-05-23-3B1W 06-07-23-4A1W 06-26-23-3B1W 06-01-23-3A1W 06-05-23-4A1W 06-08-23-3B1W 06-26-23-4A1W',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Sterling Heights',
#   'state': 'MI',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92891',
#   'recalling_firm': 'Asmus Seasoning, Inc.',
#   'address_1': '36625 Metro Ct',
#   'address_2': '',
#   'postal_code': '48312-1060',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Letter',
#   'distribution_pattern': 'MI',
#   'recall_number': 'F-1482-2023',
#   'product_description': 'Asmus Seasonings Asian Spice Blend 18oz clear plastic bottle, UPC 7 18122 95603 6, item number 233944, 12 bottle per wholesale case',
#   'product_quantity': '24 bottles',
#   'reason_for_recall': 'undeclared sesame',
#   'recall_initiation_date': '20230816',
#   'center_classification_date': '20230829',
#   'termination_date': '20230829',
#   'report_date': '20230906',
#   'code_info': 'Lot No. 23122'},
#  {'status': 'Ongoing',
#   'city': 'Englewood Cliffs',
#   'state': 'NJ',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92853',
#   'recalling_firm': 'Conopco DBA Unilever',
#   'address_1': '700 Sylvan Ave',
#   'address_2': '',
#   'postal_code': '07632-3113',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'Distributed nationwide.',
#   'recall_number': 'F-1514-2023',
#   'product_description': 'Knorr Estrellitas con Tomate Tomato Based Star Pasta Soup Mix 3.5 oz UPC: 048001716193',
#   'product_quantity': '215,000 cases',
#   'reason_for_recall': 'Undeclared egg',
#   'recall_initiation_date': '20230810',
#   'center_classification_date': '20230913',
#   'report_date': '20230920',
#   'code_info': 'Best buy dates prior to and including July 6, 2024',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Seattle',
#   'state': 'WA',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92830',
#   'recalling_firm': 'David Oppenheimer & Company I LLC',
#   'address_1': '180 Nickerson St Ste 211',
#   'address_2': '',
#   'postal_code': '98109-1631',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'Distributed in FL, GA, IL, IN, KY, MI, NC, NY, OH, PA, TN, TX, VA, and WI.',
#   'recall_number': 'F-1494-2023',
#   'product_description': 'Zespri Organic Green Kiwi, product of New Zealand, perishable, packaged in plastic clamshell, net wt. 1lb. UPC 818849020093. Distributed by The Oppenheimer Group, 180 Nickerson Street, Suite 211 Seattle WA.  Zespri Organic Green Kiwi, product of New Zealand, perishable, packaged in plastic clamshell, net wt. 3lb, item #7953.',
#   'product_quantity': '4568 cases (12/1lb. containers per case); 332 cases (6/3lb. containers per case)',
#   'reason_for_recall': 'Listeria monocytogenes',
#   'recall_initiation_date': '20230808',
#   'center_classification_date': '20230908',
#   'report_date': '20230920',
#   'code_info': 'No codes on retail 1lb. or 3lb.s plastic clamshell container. Oppenheimer lot code on the master carton: WO00278238.   Non-recall product in 1lb or 3lb. clamshell container will include a white sticker with the packed-on date and the work order number.',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Sylmar',
#   'state': 'CA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92762',
#   'recalling_firm': 'Fantasy Cookie Corporation',
#   'address_1': '12800 Arroyo St',
#   'address_2': '',
#   'postal_code': '91342-5301',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'U.S. distribution to the following: PA, FL, CA, TX, IL, WA, CA, AZ, CT  No foreign distribution.',
#   'recall_number': 'F-1509-2023',
#   'product_description': "Trader Joe's Dark Chocolate Chunk and Almond Cookies Net Wt. 13 oz.",
#   'product_quantity': '110,088 units',
#   'reason_for_recall': 'Foreign object; rocks.',
#   'recall_initiation_date': '20230724',
#   'center_classification_date': '20230912',
#   'termination_date': '20230919',
#   'report_date': '20230920',
#   'code_info': '10/17/2023 A5, 10/17/2023 B5, 10/18/2023 A5, 10/18/2023 B5, 10/19/2023 A5, 10/19/2023 B5, 10/20/2023 A5, 10/20/2023 B5, 10/21/2023 A5, 10/21/2023 B5.',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Winnemucca',
#   'state': 'NV',
#   'country': 'United States',
#   'classification': 'Class III',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92809',
#   'recalling_firm': 'RUBY MOUNTAIN SPRING WATER',
#   'address_1': '4610 Grass Valley Rd',
#   'address_2': '',
#   'postal_code': '89445-4098',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'U.S. distribution to the following: NV.  No foreign distribution.',
#   'recall_number': 'F-1492-2023',
#   'product_description': 'Ruby Mountain Spring Water 3 and 5 gallon plastic water jugs',
#   'product_quantity': '1,350 bottles',
#   'reason_for_recall': "Firm's sample revealed positive findings for coliforms.",
#   'recall_initiation_date': '20230801',
#   'center_classification_date': '20230901',
#   'report_date': '20230913',
#   'code_info': 'N/A'},
#  {'status': 'Completed',
#   'city': 'Keene',
#   'state': 'NH',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92757',
#   'recalling_firm': 'C & S Wholesale Grocers Inc.',
#   'address_1': '7 Corporate Dr',
#   'address_2': '',
#   'postal_code': '03431-5042',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'NY, NJ, CT',
#   'recall_number': 'F-1464-2023',
#   'product_description': "The following items sold at Stop & Shop stores located in the New York Metro Region:  Tofurky Holiday Ham Roast Nasoya Tofu X-Firm Twin Pack Field Roast Apple Vegan Sausage Field Roast Veggie Burger Lightlife Jackfruit Nasoya Thai Basil Dumpling Field Roast Italian Sausage Field Roast Apple Sausage BBQ Jackfruit Tex Mex Jackfruit Lightlife Sausage Chorizo  Nasoya Organic Tofu Firm Nasoya Zesty Mex Skillet Field Roast Chipotle Sausage Nasoya Super Firm Sprouted Tofu Lightlife Smart Sausage Italian Lightlife Smart Slice Turkey Nasoya Extra Firm Tofu Lightlife Smart Bacon Upton's Naturals Jackfruit Thai Curry Smart Dogs Plant Based Hot Dogs Nasoya Organic Super Firm Tofu Tofurky Italian Sausage Lightlife Smart Ground Crumbles Lightlife Smart Ground Mexican Crumbles Tofurky Oven Roasted Deli Slices",
#   'product_quantity': '29,469 cases of various products, styles of pack, case sizes and counts',
#   'reason_for_recall': 'Perishable products were not held at an appropriate temperature.',
#   'recall_initiation_date': '20230719',
#   'center_classification_date': '20230825',
#   'report_date': '20230906',
#   'code_info': 'Unit UPCs: 2558311087 2548400701 3803161180 3803140650 5980600329 2548400703 3803141215 3803141217 5980600302 5980600325 4345410065 2548400010 2548400735 3803161216 2548400657 4345410062 4345410020 8826744936 4345410104 5107000610 4345410012 2548400012 2558300602 4345410015 4345410018 2558366873'},
#  {'status': 'Ongoing',
#   'city': 'Stanwood',
#   'state': 'WA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92907',
#   'recalling_firm': 'Twin City Foods, Inc.',
#   'address_1': '10120 269th Pl Nw Ste A',
#   'address_2': '',
#   'postal_code': '98292-4736',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'E-Mail',
#   'distribution_pattern': 'distributed nationwide in the US and in Costa Rica, China, and Japan.',
#   'recall_number': 'F-1503-2023',
#   'product_description': 'Individually Quick Frozen (IQF) Corn distributed in BULK TOTES (1650lbs and 1750lbs) to consignees for further processing. Bulk tote labels have cooking instructions.   Individually Quick Frozen (IQF) Super Sweet Corn, foodservice item, packaged in 32oz. plastic bag, 12 bags per case.  The poly bag is stamped with lot code and Product of USA. No UPC.  Individually Quick Frozen (IQF) Super Sweet Cut Corn, food service item, packaged in 40oz. poly bags, 12 bags per case. The poly bag is clear (no printing except the coding). Master case label declares KFC Super Sweet Cut Corn, 12-40oz bags, 30lbs. UPC 885251248124.',
#   'product_quantity': 'Bulk Totes Total: 66,300 lbs; Corn: 610 cases (12/32oz. bags per case) and 635 cases (12/40oz. bags per case)',
#   'reason_for_recall': 'Listeria monocytogenes',
#   'recall_initiation_date': '20230818',
#   'center_classification_date': '20230912',
#   'report_date': '20230920',
#   'code_info': 'Bulk Totes: Shop Orders 21369 and 21373.  Manufactured on 8/21/2022. Corn 32oz: 83012. KFC Corn 40oz: Use by Oct 24 2024 82972 554922 822315.',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Saint Paul',
#   'state': 'MN',
#   'country': 'United States',
#   'classification': 'Class III',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92870',
#   'recalling_firm': 'Twin Cities Co-Op Partners Inc.',
#   'address_1': '744 Vandalia St',
#   'address_2': '',
#   'postal_code': '55114-1303',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'IA, MI, MN, WI',
#   'recall_number': 'F-1496-2023',
#   'product_description': 'La Reyna Diablo Salsa.  Red Diablo Salsa, Hot.  Product Code 1782.  Net Wt 8 oz.  UPC 7 52830-92710 0.  Ingredients:  Dried Red Peppers, Tomatoes, Onion, Salt, Sesame Seed, Garlic, Olive Oil.  Keep Refrigerated.  La Reyna, 202 4th, Vinton IA  42349',
#   'product_quantity': '720 containers total',
#   'reason_for_recall': 'Dips and sauces received out of temperature specifications. Product was not quarantined; product was shipped to customers.',
#   'recall_initiation_date': '20230811',
#   'center_classification_date': '20230908',
#   'termination_date': '20230913',
#   'report_date': '20230920',
#   'code_info': 'Best By:  8/18/2023',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Fresno',
#   'state': 'CA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92872',
#   'recalling_firm': 'Lyons Magnus LLC',
#   'address_1': '3158 E Hamilton Ave',
#   'address_2': '',
#   'postal_code': '93702-4163',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'AR, FL, GA, IA, KY, LA, MI, NC, OH, PA, TN TX, WI',
#   'recall_number': 'F-1485-2023',
#   'product_description': 'GFS Harvest Valley Cranberry/Grape Juice packaged in 4 fl oz opaque white plastic cup 96 cups per case',
#   'product_quantity': '1496 cases',
#   'reason_for_recall': 'Signs of bloating in juice cups',
#   'recall_initiation_date': '20230811',
#   'center_classification_date': '20230830',
#   'report_date': '20230906',
#   'code_info': 'Item No. 5694 Batch Code: 9213, 1613 Best By: 12/05/23, 01/06/24'},
#  {'status': 'Ongoing',
#   'city': 'Milford',
#   'state': 'NY',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '92753',
#   'recalling_firm': 'Cooperstown Cheese Company, LLC',
#   'address_1': '107 Oxbow Rd',
#   'address_2': '',
#   'postal_code': '13807-1131',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': '',
#   'distribution_pattern': 'NY',
#   'recall_number': 'F-1490-2023',
#   'product_description': 'Cooperstown Cheese Company 1. Jersey Girl 2. Toma Celena  3.  Abbie 4.  SK 5. Jersey Girl with garlic/rosemary  6.Jersey Girl spring onion 7. Bobby s got the Blues  8.Toma Torino 9. Jersey Gold with garlic 10. Abbie. 11. Jersey Gold 12. Marielle',
#   'product_quantity': '1400 lbs.',
#   'reason_for_recall': 'Cheese may be contaminated with Listeria monocytogenes.',
#   'recall_initiation_date': '20230721',
#   'center_classification_date': '20230901',
#   'report_date': '20230913',
# ...
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'One consignee is a wholesale warehouse. The remainder of the consignees are grocery stores and food service establishments.',
#   'recall_number': 'F-1425-2022',
#   'product_description': 'COLBY JACK CHEESE  Ingredients: Pasteurized Milk, Cheese Culture, Salt, Enzymes and Annatto.  DISTRIBUTED BY PARIS BROTHERS, INC. KANSAS CITY, MO 64161\t  UPC: 033954252232  Net wt. 1 LB(16OZ) 453G        Carton Label (not available to consumers)  ITEM ID: 02201803  PARIS BROTHERS, INC  8800 NE UNDERGROUND DR  KANSAS CITY, MO 64161  (816) 455-4189  PARIS BROTHERS COLBY JACK 10-1 LB EW    UPC: 033954252232      No label description for: Paris Brothers Colby Jack *14-1 lb RW  Item 2201845',
#   'product_quantity': '2981 lbs (total)',
#   'reason_for_recall': 'Environmental samples positive for Listeria.',
#   'recall_initiation_date': '20220524',
#   'center_classification_date': '20220714',
#   'termination_date': '20221024',
#   'report_date': '20220713',
#   'code_info': 'Lot: 05042022 Exp Date: 8/3/22    BEST BY: 2022/08/03 or BEST BY: 2022/08/04',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Kent',
#   'state': 'WA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '91168',
#   'recalling_firm': 'Taylor Farms Northwest, LLC',
#   'address_1': '8030 S 228th St Bldg A',
#   'address_2': '',
#   'postal_code': '98032-2987',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'Distributed in Washington only.',
#   'recall_number': 'F-0187-2023',
#   'product_description': 'Taylor Farms Jicama Sticks, Refrigerated & Ready To Eat product, packaged in a clear plastic clamshell container, net wt. 14 oz.  Distributed by Taylor Farms NW Kent, WA 98032. UPC 30223 11248.',
#   'product_quantity': '539 units',
#   'reason_for_recall': 'Metal fragment.  A piece of metal about 3/4 inch was found in retail package.',
#   'recall_initiation_date': '20221116',
#   'center_classification_date': '20221206',
#   'termination_date': '20221213',
#   'report_date': '20221214',
#   'code_info': 'Sell By: 11/13/2022 Sell By: 11/14/2022 Sell By: 11/15/2022 Sell By: 11/16/2022 Sell By: 11/17/2022'},
#  {'status': 'Terminated',
#   'city': 'Kansas City',
#   'state': 'MO',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90300',
#   'recalling_firm': 'Paris Brothers Inc',
#   'address_1': '8800 Ne Underground Dr',
#   'address_2': '',
#   'postal_code': '64161-9746',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'One consignee is a wholesale warehouse. The remainder of the consignees are grocery stores and food service establishments.',
#   'recall_number': 'F-1424-2022',
#   'product_description': 'MILD CHEDDAR CHEESE  Ingredients: Pasteurized Milk, Cheese Culture, Salt, Enzymes and Annatto  DISTRIBUTED BY PARIS BROTHERS, INC. KANSAS CITY, MO 64161\t  UPC: 033954252225  Net wt. 1 LB(16OZ) 453G      Carton Label (not available to consumers)  ITEM ID: 02201804  PARIS BROTHERS, INC  8800 NE UNDERGROUND DR  KANSAS CITY, MO 64161  (816) 455-4189  PARIS BROTHERS MILD CHEDDAR 10-1 LB EW    UPC: 033954252225    ITEM ID: 02201804  PARIS BROTHERS, INC  8800 NE UNDERGROUND DR  KANSAS CITY, MO 64161  (816) 455-4189  PARIS BROTHERS MILD CHEDDAR 10-1 LB EW    UPC: 033954252225    No label example for PARIS BROTHERS MILD CHEDDAR *14-1 LB RW   ITEM 2201032',
#   'product_quantity': '2981 lbs (total)',
#   'reason_for_recall': 'Environmental samples positive for Listeria.',
#   'recall_initiation_date': '20220524',
#   'center_classification_date': '20220714',
#   'termination_date': '20221024',
#   'report_date': '20220713',
#   'code_info': 'Lot: 05042022 Exp Date: 11/4/22  Lot: 05052022 Exp Date: 11/5/22    BEST BY: 2022/11/04 or BEST BY: 2022/11/05',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Tampa',
#   'state': 'FL',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90592',
#   'recalling_firm': 'Refresco Beverages US Inc',
#   'address_1': '8112 Woodlnd Ctr Blvd',
#   'address_2': '',
#   'postal_code': '33614-2403',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'E-Mail',
#   'distribution_pattern': 'Stores throughout AZ, CA, IL, IN, KY, ME, NV, NY, OH, PA, SC, UT, VA, WA, WI',
#   'recall_number': 'F-1538-2022',
#   'product_description': 'Clear American brand "Strawberry Punch Snow Cone" flavored sparkling water beverage with other natural flavors; 1-liter clear plastic bottles. Best if Used by dates in August-October 2022.',
#   'product_quantity': '87, 859 cases (12 one-liter bottles per case)',
#   'reason_for_recall': 'The product may contain trace amounts of coconut, which is not declared on the labeling. Laboratory analysis was unable to detect any coconut allergen, however the firm has decided to recall out of an abundance of caution.',
#   'recall_initiation_date': '20220707',
#   'center_classification_date': '20220806',
#   'termination_date': '20221020',
#   'report_date': '20220817',
#   'code_info': 'BEST IF USED BY Aug 01 22 BEST IF USED BY Aug 04 22 BEST IF USED BY Aug 05 22 BEST IF USED BY Aug 16 22 BEST IF USED BY Aug 17 22 BEST IF USED BY Aug 18 22 BEST IF USED BY Aug 22 22 BEST IF USED BY Aug 29 22 BEST IF USED BY Sep 03 22 BEST IF USED BY Sep 09 22 BEST IF USED BY Sep 14 22 BEST IF USED BY Sep 15 22 BEST IF USED BY Sep 29 22 BEST IF USED BY Sep 30 22 BEST IF USED BY Oct 06 22 BEST IF USED BY Oct 08 22 BEST IF USED BY Oct 11 22 BEST IF USED BY Oct 17 22 BEST IF USED BY Oct 20 22 BEST IF USED BY Oct 23 22',
#   'more_code_info': ''},
#  {'status': 'Ongoing',
#   'city': 'Rockwell',
#   'state': 'NC',
#   'country': 'United States',
#   'classification': 'Class III',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90485',
#   'recalling_firm': 'Select Bakery Inc.',
#   'address_1': '607 Palmer Rd',
#   'address_2': '',
#   'postal_code': '28138-8577',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Letter',
#   'distribution_pattern': 'Product was shipped to the following states: GA, NC & SC.',
#   'recall_number': 'F-1697-2022',
#   'product_description': 'Select Bakery Old Fashion Orange Creme Cake Net Wt. 3 Oz (85g) Select Bakery, Inc., Rockwell, N.C. 28138 UPC 0 28598 10005 6',
#   'product_quantity': '45cs/45/3oz packages',
#   'reason_for_recall': 'Undeclared Soy',
#   'recall_initiation_date': '20220622',
#   'center_classification_date': '20220907',
#   'report_date': '20220914',
#   'code_info': 'All date codes'},
#  {'status': 'Terminated',
#   'city': 'Newburg',
#   'state': 'PA',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90805',
#   'recalling_firm': 'Keswick Creamery at Carrock Farms LLC',
#   'address_1': '114 Lesher Rd',
#   'address_2': '',
#   'postal_code': '17240-9300',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Telephone',
#   'distribution_pattern': 'Distributed to farm stores and farmers markets in Washington DC, MD, VA, and PA',
#   'recall_number': 'F-1798-2022',
#   'product_description': 'Aged raw milk cheese "Calverley" 4 oz to 12 oz packages',
#   'product_quantity': '23 lbs',
#   'reason_for_recall': 'All products manufactured by the firm have the potential to be contaminated with Listeria monocytogenes.',
#   'recall_initiation_date': '20220825',
#   'center_classification_date': '20220926',
#   'termination_date': '20221103',
#   'report_date': '20221005',
#   'code_info': 'Batch 317'},
#  {'status': 'Terminated',
#   'city': 'Vancouver',
#   'state': '',
#   'country': 'Canada',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90561',
#   'recalling_firm': 'ARBORYPHARM FOODS INC.',
#   'address_1': '254-60 Smithe St',
#   'address_2': '',
#   'postal_code': '',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'U.S. distribution to the following: nationwide throughout the U.S.  No foreign distribution.',
#   'recall_number': 'F-1428-2022',
#   'product_description': 'Natreve Vegan Protein Powder 10 servings, 13.1oz (371g), UPC 628831120003 18 servings, 1.47lbs/23.53oz (667g), UPC 628831110073',
#   'product_quantity': '6,683 units',
#   'reason_for_recall': 'Undeclared allergen; milk.',
#   'recall_initiation_date': '20220703',
#   'center_classification_date': '20220714',
#   'termination_date': '20220929',
#   'report_date': '20220720',
#   'code_info': 'Lot# 46359, Best Before Date: 2/2025 10 servings, 13.1oz (371g), UPC 628831120003  Lot# 46360, Best Before Date: 2/2025 18 servings, 1.47lbs/23.53oz (667g), UPC 628831110073  10 servings, 13.1oz (371g), UPC 628831120003',
#   'more_code_info': ''},
#  {'status': 'Terminated',
#   'city': 'Inver Grove Heights',
#   'state': 'MN',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90694',
#   'recalling_firm': 'Russ Davis Wholesale, LLC',
#   'address_1': '6085 Claude Way',
#   'address_2': '',
#   'postal_code': '55076-4432',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'IA, MI, MN, ND, SD, WI',
#   'recall_number': 'F-1759-2022',
#   'product_description': 'Broccoli, Carrot, Strawberry, Red Grape.  Net Wt. 11 oz.  Item 80820   Packaged under the following brands:   Crazy Fresh, quick & easy, and grocery store branded.',
#   'product_quantity': '87,915 units total',
#   'reason_for_recall': 'Various vegetable and fruit products are recalled due to inadequate sanitizer in wash water.',
#   'recall_initiation_date': '20220729',
#   'center_classification_date': '20220922',
#   'termination_date': '20220923',
#   'report_date': '20220928',
#   'code_info': 'Lot Code:  X5981784, X5984453, X5989184, X5987104, X5993395, X5996008, X5998730.   Best by Dates:  7/28-8/4/2022'},
#  {'status': 'Terminated',
#   'city': 'Bensenville',
#   'state': 'IL',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90844',
#   'recalling_firm': 'Muktanand Foods Inc',
#   'address_1': '483 Thomas Dr',
#   'address_2': '',
#   'postal_code': '60106-1618',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Press Release',
#   'distribution_pattern': 'AL CO GA IA IL KS MN MO NC NE NJ OH SC WI',
#   'recall_number': 'F-1748-2022',
#   'product_description': 'ANKUR Golden Raisin; 14 Oz (400 gm); UPC Code 8904 1740 10327; packaged in clear plastic bag, 20 bags per wholesale case',
#   'product_quantity': '485 cases',
#   'reason_for_recall': 'Undeclared sulfites',
#   'recall_initiation_date': '20220908',
#   'center_classification_date': '20220921',
#   'termination_date': '20221202',
#   'report_date': '20220928',
#   'code_info': 'All product regardless of the presence or absence of a batch number on the product'},
#  {'status': 'Terminated',
#   'city': 'Spokane',
#   'state': 'WA',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90781',
#   'recalling_firm': 'Scone Ranger Inc',
#   'address_1': '606 W 2nd Ave',
#   'address_2': '',
#   'postal_code': '99201-4411',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Telephone',
#   'distribution_pattern': 'Distributed in WA',
#   'recall_number': 'F-1736-2022',
#   'product_description': 'Lemon Blueberry Vegan Scones.  Product distributed in bulk cases and it is sold directly to consumers.   The ingredients statement is read in parts: "***Lemon Blueberry Vegan Scones *** All purpose flour (wheat flour, malted barley flour, niacin, Iron (reduced), thiaminmononitrate, riboflavin, folic acid), sugar, powdered sugar (sugar, cornstarch), natural oil blend (palm fruit and soybean oils), water, contains less than 2% salt, natural flavor, monoglycerides of vegetable fatty acids, soybean lecithin, vitamin A palmitate, beta-carotene color, lactic acid, potassium sorbate and calcium disodium edta to protect freshness, blueberries, almond milk, calcium carbonate, sea salt, potassium citrate, sunflower lecithin, gellan gum, natural flavors, vitamin A palmitate, vitamin D2, D-alpha-tocopherol (natural vitamin E), salt, baking powder (cornstarch, monocalcium phosphate, sodium bicarbonate, sodium acid pyrophosphate), baking soda (sodium bicarbonate), lemons***".',
#   'product_quantity': '24 scones',
#   'reason_for_recall': 'Undeclared milk. Vegan scones contain margarine but labeling does not declare margarine or milk.',
#   'recall_initiation_date': '20220818',
#   'center_classification_date': '20220916',
#   'termination_date': '20221017',
#   'report_date': '20220928',
#   'code_info': 'NO codes'},
#  {'status': 'Terminated',
#   'city': 'Inver Grove Heights',
#   'state': 'MN',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90694',
#   'recalling_firm': 'Russ Davis Wholesale, LLC',
#   'address_1': '6085 Claude Way',
#   'address_2': '',
#   'postal_code': '55076-4432',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'IA, MI, MN, ND, SD, WI',
#   'recall_number': 'F-1779-2022',
#   'product_description': "Mango Tango.  Contains:  Mango, Pineapple, Strawberry, Oranges, Blueberries.  Keep Refrigerated.   Item 89273.  Net Wt. 16 oz.  Kowalski's Markets.",
#   'product_quantity': '87,915 units total',
#   'reason_for_recall': 'Various vegetable and fruit products are recalled due to inadequate sanitizer in wash water.',
#   'recall_initiation_date': '20220729',
#   'center_classification_date': '20220922',
#   'termination_date': '20220923',
#   'report_date': '20220928',
#   'code_info': 'Lot Code:  X5942740, X5945223, X5948001, X5950661, X5953255, X5956892, X5959320, X5962106, X5964709, X5967440, X5969931, X5973249, X5976070, X5978921, X5981628, X5984281, X5986873, X5990547, X5993026, X5995803, X5998344, X6001144.   Use by Dates:  7/9-8/2/2022'},
#  {'status': 'Terminated',
#   'city': 'Van Nuys',
#   'state': 'CA',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '90714',
#   'recalling_firm': "That's it. Nutrition, LCC",
#   'address_1': '10106 Hart Street',
#   'address_2': '',
#   'postal_code': '91405',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Letter',
#   'distribution_pattern': 'U.S. distribution to the following: CO, WA, CA, IL, NH, CT, NY, IA  Foreign distribution to the following: Canada, Hong Kong, Singapore',
#   'recall_number': 'F-1741-2022',
#   'product_description': "That's It. Dark Chocolate Raisin Truffles Net WT. 3.5 oz, 5.0 oz, and 16.0 oz Ingredients: Organic Raisins, Organic Dark Chocolate (Organic Unsweetened Chocolate, Organic Sugar, Organic Cocoa Butter) Prepared by: That's It Nutrition LLC Los Angeles, CA 90014 CA.THATSITFRUIT>COM 888-862-5235 Certified Organic by NFC Product of USA",
#   'product_quantity': '',
#   'reason_for_recall': 'CFIA testing of the products revealed casein and whey which caused undeclared milk in the products.',
#   'recall_initiation_date': '20220804',
#   'center_classification_date': '20220916',
#   'termination_date': '20220919',
#   'report_date': '20220928',
#   'code_info': 'Lot/expiration date ranging from March 23, 2023-July 8, 2024'},
#  ...]

# %%
# One way
pd.DataFrame(data['results']).head(3)
# Out:
#        status              city state        country classification openfda  \
# 0     Ongoing           Seattle    WA  United States        Class I      {}
# 1  Terminated            Dayton    OH  United States       Class II      {}
# 2     Ongoing  Englewood Cliffs    NJ  United States       Class II      {}
#
#   product_type event_id                     recalling_firm  \
# 0         Food    92830  David Oppenheimer & Company I LLC
# 1         Food    92888                       Cassanos Inc
# 2         Food    92853               Conopco DBA Unilever
#
#                   address_1  ... recall_number  \
# 0  180 Nickerson St Ste 211  ...   F-1495-2023
# 1          1700 E Stroop Rd  ...   F-1510-2023
# 2            700 Sylvan Ave  ...   F-1516-2023
#
#                                  product_description product_quantity  \
# 0  Zespri Organic Green Kiwi, product of New Zeal...         1 pallet
# 1  Cassano's The Pizza King Premium Pizza Dough o...              180
# 2  Knorr Letras con Tomate Tomato Based Alphabet ...    230,000 cases
#
#                  reason_for_recall recall_initiation_date  \
# 0           Listeria monocytogenes               20230808
# 1  Undeclared Allergen - Soy Flour               20230821
# 2                   Undeclared egg               20230810
#
#   center_classification_date report_date  \
# 0                   20230908    20230920
# 1                   20230913    20230920
# 2                   20230913    20230920
#
#                                            code_info more_code_info  \
# 0                                               none
# 1  Lot: 193, 194 Expiration: 01/10/24, 01/11/24 I...
# 2  Best buy dates prior to and including July 6, ...
#
#   termination_date
# 0              NaN
# 1         20230915
# 2              NaN
#
# [3 rows x 25 columns]

# %%
# Another way (### > give the path using jaon_normalize command)
pd.json_normalize(data, record_path='results').head() #info_path
# Out:
#        status              city state        country classification  \
# 0     Ongoing           Seattle    WA  United States        Class I
# 1  Terminated            Dayton    OH  United States       Class II
# 2     Ongoing  Englewood Cliffs    NJ  United States       Class II
# 3     Ongoing          Stanwood    WA  United States       Class II
# 4     Ongoing          Stanwood    WA  United States       Class II
#
#   product_type event_id                     recalling_firm  \
# 0         Food    92830  David Oppenheimer & Company I LLC
# 1         Food    92888                       Cassanos Inc
# 2         Food    92853               Conopco DBA Unilever
# 3         Food    92907              Twin City Foods, Inc.
# 4         Food    92907              Twin City Foods, Inc.
#
#                   address_1 address_2  ... recall_number  \
# 0  180 Nickerson St Ste 211            ...   F-1495-2023
# 1          1700 E Stroop Rd            ...   F-1510-2023
# 2            700 Sylvan Ave            ...   F-1516-2023
# 3   10120 269th Pl Nw Ste A            ...   F-1504-2023
# 4   10120 269th Pl Nw Ste A            ...   F-1505-2023
#
#                                  product_description  \
# 0  Zespri Organic Green Kiwi, product of New Zeal...
# 1  Cassano's The Pizza King Premium Pizza Dough o...
# 2  Knorr Letras con Tomate Tomato Based Alphabet ...
# 3  Individually Quick Frozen (IQF) Corn, distribu...
# 4  Kernel Corn, BEST PRICE TOPVALU, net wt. per b...
#
#                                     product_quantity  \
# 0                                           1 pallet
# 1                                                180
# 2                                      230,000 cases
# 3  Bulk Cases Total 69,134 cs (Corn 12/1kg bags =...
# 4  TopValu 300g = 1,108 cs; Signature Select = 1,...
#
#                  reason_for_recall recall_initiation_date  \
# 0           Listeria monocytogenes               20230808
# 1  Undeclared Allergen - Soy Flour               20230821
# 2                   Undeclared egg               20230810
# 3           Listeria monocytogenes               20230818
# 4           Listeria monocytogenes               20230818
#
#   center_classification_date report_date  \
# 0                   20230908    20230920
# 1                   20230913    20230920
# 2                   20230913    20230920
# 3                   20230912    20230920
# 4                   20230912    20230920
#
#                                            code_info more_code_info  \
# 0                                               none
# 1  Lot: 193, 194 Expiration: 01/10/24, 01/11/24 I...
# 2  Best buy dates prior to and including July 6, ...
# 3  BULK CASES have the following codes and USE BY...
# 4  BEST PRICE TOPVALU: 2024.02.23  Signature Sele...
#
#   termination_date
# 0              NaN
# 1         20230915
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# **Note:**
#
# We would only be covering these 2 modules at a later time. However, one may like to look at the specific chapters listed below.
#
# Streamlined Data Ingestion with pandas
# - Chapter 4: Importing JSON Data and Working with APIs
#
# Intermediate Importing Data in Python
# - Chapter 2: Interacting with APIs to import data from the web
