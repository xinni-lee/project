# %% [markdown]
# # 1: Risk factors
#
# https://data.who.int/countries/702
#
# <p>Prevalence of hypertension: Age-standardized prevalence of hypertension among adults aged 30 to 79 years (%)
# <p>Adult obesity: Age-standardized prevalence of obesity among adults (18+ years)
# <p>Tobacco: Age-standardized prevalence of tobacco use among persons 15 years and older (%)

# %%
# !pip install sqlalchemy
# !pip install psycopg2

# %%
import pandas as pd
import sqlalchemy as db

# %%
# !pip install sqlalchemy_utils

# %%
from sqlalchemy_utils import create_database

# As an example
# ASSUME username is postgres and password is admin, and port number is 5435
# If one wants to create a *NEW* db, say, starter, please note the make up of the below string ***

engine = db.create_engine('postgresql://postgres:admin@localhost:5432/project')

# create database
create_database(engine.url)

# release resources associated with engine
engine.dispose()

# %%
# Create connection engine

# Using username postgres, password admin, and EXISTING database testdb
engine = db.create_engine('postgresql://postgres:admin@localhost:5432/project') 

conn = engine.raw_connection()

# %%
df = pd.read_sql('SELECT * FROM obesity', conn)
df
# Out:
# C:\Users\xinni\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#                    IND_ID     IND_CODE IND_UUID IND_PER_CODE  DIM_TIME  \
# 0      BEFA58BNCD_BMI_30A  NCD_BMI_30A  BEFA58B  NCD_BMI_30A      1990
# 1      BEFA58BNCD_BMI_30A  NCD_BMI_30A  BEFA58B  NCD_BMI_30A      1994
# 2      BEFA58BNCD_BMI_30A  NCD_BMI_30A  BEFA58B  NCD_BMI_30A      2001
# 3      BEFA58BNCD_BMI_30A  NCD_BMI_30A  BEFA58B  NCD_BMI_30A      2004
# 4      BEFA58BNCD_BMI_30A  NCD_BMI_30A  BEFA58B  NCD_BMI_30A      2007
# ...                   ...          ...      ...          ...       ...
# 20785  BEFA58BNCD_BMI_30A  NCD_BMI_30A  BEFA58B  NCD_BMI_30A      1995
# 20786  BEFA58BNCD_BMI_30A  NCD_BMI_30A  BEFA58B  NCD_BMI_30A      1997
# ...

# %%
# %sql postgresql:///obesity
SELECT *
FROM obesity 
LIMIT 3;
# Out:
#   Input In [12]
#     SELECT *
#             ^
# SyntaxError: invalid syntax

# %%
# %sql
SELECT * 
FROM obesity
LIMIT 3;
# Out:
#   Input In [14]
#     SELECT *
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![Screenshot%202024-11-26%20133940.jpg](attachment:Screenshot%202024-11-26%20133940.jpg)

# %% [markdown]
# ![Screenshot%202024-11-27%20171944.jpg](attachment:Screenshot%202024-11-27%20171944.jpg)

# %% [markdown]
# # 2: Principal Causes of Death
#
# https://data.gov.sg/datasets/d_48143a2b16027afcadeb362352b0266a/view
#
# <p>Top 10 principal causes of death
#
# The Mortality Tabulation List of the International Classification of Diseases - Tenth Revision has replaced the Ninth Revision as the adopted code set for the derivation of causes of death

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3: Prevalence of Hypertension, Diabetes, High Total Cholesterol, Obesity and Daily Smoking
#
# https://data.gov.sg/datasets?agencies=Ministry+of+Health+(MOH)&page=1&topics=health&resultId=d_efea9966c502767122171c61d88062db
#
# <p>Prevalence of hypertension, diabetes, high total cholesterol, obesity and daily smoking among Singapore residents aged 18 to 69 years.
#
# <p>Definitions:
# <p>- Hypertension: ≥ 140/90 mmHg
# <p>- Diabetes: Fasting plasma glucose ≥ 6.9 mmol/l
# <p>- Hyperlipidaemia: LDL-Cholesterol ≥ 4.1 mmol/l
# <p>- Obesity: BMI ≥ 30kg/m2
# <p>- Daily Smoking: Smokes cigarettes at least once a day
# <p>- na - not available

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4: Population and Population Structure
# https://www.singstat.gov.sg/find-data/search-by-theme/population/population-and-population-structure/latest-data

# %% [markdown]
# ![image.png](attachment:image.png)
